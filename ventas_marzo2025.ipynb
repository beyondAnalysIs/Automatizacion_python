# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# Establecer una semilla para reproducibilidad
np.random.seed(42)

# Crear listas de valores posibles para cada columna categórica
productos = ['Laptop', 'Smartphone', 'Tablet', 'Monitor', 'Teclado', 'Mouse', 'Auriculares', 'Impresora']
categorias = ['Electrónica', 'Informática', 'Accesorios', 'Periféricos']
regiones = ['Norte', 'Sur', 'Este', 'Oeste', 'Centro']
vendedores = ['Juan Pérez', 'María García', 'Carlos López', 'Ana Martínez', 'Luis Rodríguez']

# Definir fechas en un rango de los últimos 6 meses
fecha_base = datetime(2025, 3, 1)
fechas = [(fecha_base + timedelta(days=i*2)).strftime('%Y-%m-%d') for i in range(20)]
# Mezclamos las fechas para que no estén en orden secuencial
random.shuffle(fechas)

# Crear el diccionario con datos aleatorios
datos_ventas = {
    'ID': list(range(1041, 1061)),  # IDs del 1001 al 1020 (20 filas)
    'Fecha': fechas,
    'Producto': [random.choice(productos) for _ in range(20)],
    'Categoria': [random.choice(categorias) for _ in range(20)],
    'Region': [random.choice(regiones) for _ in range(20)],
    'Vendedor': [random.choice(vendedores) for _ in range(20)],
    'Cantidad': np.random.randint(1, 11, size=20),  # Cantidades entre 1 y 10
    'Precio': np.round(np.random.uniform(100, 1000, size=20), 2)  # Precios entre 100 y 1000
}

# Convertir a DataFrame para visualizar (opcional)
df = pd.DataFrame(datos_ventas)
print(df)

# Si quieres exportar a Excel
df.to_excel('datos_ventas_2025-03.xlsx', index=False)
print("\nDatos exportados a 'datos_ventas.xlsx'")

# También puedes ver el diccionario original
print("\nDiccionario de datos:")
for clave, valores in datos_ventas.items():
    print(f"{clave}: {valores[:3]}...")  # Mostrar solo los primeros 3 v
# Out:
#       ID       Fecha    Producto    Categoria  Region        Vendedor  \
# 0   1041  2025-03-11   Impresora  Electrónica  Centro      Juan Pérez
# 1   1042  2025-03-13     Monitor  Electrónica   Oeste      Juan Pérez
# 2   1043  2025-03-23       Mouse   Accesorios   Oeste    María García
# 3   1044  2025-03-25   Impresora  Periféricos   Norte    Carlos López
# 4   1045  2025-03-27      Laptop  Periféricos     Sur  Luis Rodríguez
# 5   1046  2025-04-08  Smartphone  Electrónica   Norte      Juan Pérez
# 6   1047  2025-03-17  Smartphone  Periféricos     Sur    María García
# 7   1048  2025-03-29  Smartphone  Electrónica   Norte  Luis Rodríguez
# 8   1049  2025-03-09      Laptop  Periféricos    Este    María García
# 9   1050  2025-03-21      Laptop  Electrónica   Norte  Luis Rodríguez
# 10  1051  2025-04-06      Tablet   Accesorios  Centro    Carlos López
# 11  1052  2025-03-31  Smartphone  Electrónica   Oeste    Ana Martínez
# 12  1053  2025-03-05  Smartphone   Accesorios   Norte      Juan Pérez
# 13  1054  2025-03-19     Teclado  Informática   Norte    María García
# 14  1055  2025-04-04  Smartphone  Periféricos   Norte    Carlos López
# 15  1056  2025-03-15     Monitor  Electrónica   Norte    Ana Martínez
# 16  1057  2025-03-07      Tablet   Accesorios    Este  Luis Rodríguez
# 17  1058  2025-03-01     Monitor  Electrónica    Este  Luis Rodríguez
# 18  1059  2025-04-02   Impresora  Informática    Este    Carlos López
# 19  1060  2025-03-03       Mouse  Informática  Centro  Luis Rodríguez
#
#     Cantidad  Precio
# 0          7  263.64
# 1          4  265.06
# 2          8  373.82
# 3          5  572.28
# 4          7  488.75
# 5         10  362.11
# 6          3  650.67
# 7          7  225.54
# 8          8  362.93
# 9          5  429.73
# 10         4  510.46
# 11         8  806.66
# 12         8  279.71
# 13         3  562.81
# 14         6  633.17
# 15         5  141.81
# 16         2  646.79
# 17         8  253.47
# 18         6  158.55
# 19         2  954.00
#
# Datos exportados a 'datos_ventas.xlsx'
#
# Diccionario de datos:
# ID: [1041, 1042, 1043]...
# Fecha: ['2025-03-11', '2025-03-13', '2025-03-23']...
# Producto: ['Impresora', 'Monitor', 'Mouse']...
# Categoria: ['Electrónica', 'Electrónica', 'Accesorios']...
# Region: ['Centro', 'Oeste', 'Oeste']...
# Vendedor: ['Juan Pérez', 'Juan Pérez', 'María García']...
# Cantidad: [7 4 8]...
# Precio: [263.64 265.06 373.82]...
